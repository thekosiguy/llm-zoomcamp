# %%
import openai
import os

# %%
from openai import OpenAI
client = OpenAI()

# %%
response = client.chat.completions.create(model="gpt-5.1",
                               messages=[{"role": "user", "content": "is it too late to join the course?"}])

# %%
response.choices[0].message.content
# Out:
# 'I’m not connected to your specific course platform, so I can’t see its enrollment status.\n\nTo figure it out quickly:\n1. Check the course page: look for “enroll,” “register,” or “join now” buttons and any listed enrollment deadline.\n2. Look for start/end dates: some courses allow late enrollment with catch-up, others close completely once they begin.\n3. If it’s through a school or program, email or message:\n   - the instructor, or  \n   - the program coordinator / registrar.\n\nIf you tell me:\n- the course name,\n- platform or school (e.g., Coursera, Udemy, a university, etc.),\nI can walk you through exactly where to look and what to ask.'
